# %%
print("hlo")
# Out:
# hlo

# %%
print("hi hlo world gm to all")
# Out:
# hi hlo world gm to all

# %%
list
l1=["apple","banana","cherry","grapes","pomagranate","blackperry"]
l1.append("orange") #add element at the end
print(l1)
# Out:
# ['apple', 'banana', 'cherry', 'grapes', 'pomagranate', 'blackperry', 'orange']

# %%
# %pip install pandas
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# %pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...

# %%
# %pip install numpy
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import pandas as pd
df = pd.read_excel("sales1.csv.xlsx")
df
# Out:
#    Transaction ID       Date Product Category                 Product Name  \
# 0           10001 2024-01-01      Electronics                iPhone 14 Pro
# 1           10002 2024-01-02  Home Appliances             Dyson V11 Vacuum
# 2           10003 2024-01-03         Clothing             Levi's 501 Jeans
# 3           10004 2024-01-04            Books            The Da Vinci Code
# 4           10005 2024-01-05  Beauty Products      Neutrogena Skincare Set
# 5           10006 2024-01-06           Sports  Wilson Evolution Basketball
# 6           10007 2024-01-07      Electronics          MacBook Pro 16-inch
# 7           10008 2024-01-08  Home Appliances         Blueair Classic 480i
# 8           10009 2024-01-09         Clothing             Nike Air Force 1
# 9           10010 2024-01-10            Books        Dune by Frank Herbert
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# ...

# %%
# %pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
# ...

# %%
df['sales']=[60,50,20,30,100,90,20,10,56,98]
df
# Out:
#    Transaction ID       Date Product Category                 Product Name  \
# 0           10001 2024-01-01      Electronics                iPhone 14 Pro
# 1           10002 2024-01-02  Home Appliances             Dyson V11 Vacuum
# 2           10003 2024-01-03         Clothing             Levi's 501 Jeans
# 3           10004 2024-01-04            Books            The Da Vinci Code
# 4           10005 2024-01-05  Beauty Products      Neutrogena Skincare Set
# 5           10006 2024-01-06           Sports  Wilson Evolution Basketball
# 6           10007 2024-01-07      Electronics          MacBook Pro 16-inch
# 7           10008 2024-01-08  Home Appliances         Blueair Classic 480i
# 8           10009 2024-01-09         Clothing             Nike Air Force 1
# 9           10010 2024-01-10            Books        Dune by Frank Herbert
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method  sales
# ...

# %%
df.iloc[0,0]
df['Transaction ID'].mean()
# Out:
# np.float64(10005.5)

# %%
import numpy as np
a1=np.array([1,6,8,8,5,4])
print(a1)
print(type(a1))
print(a1.shape)
print("hloo")
# Out:
# [1 6 8 8 5 4]
# <class 'numpy.ndarray'>
# (6,)

# %%
#data cleaning process
import pandas as pd
data = pd.read_csv("customer_feedback1.csv")
data
# Out:
#     customer_id       name   age                   feedback_text rating  \
# 0             1   John Doe  28.0                 Good service!!!    4.5
# 1             2  Mary, Ann   NaN  Nice place but food was cold..    3.8
# 2             3        NaN  35.0              Loved it!!! â¤ï¸      ?
# 3             4    Rahul@@  22.0                             NaN      4
# 4             5      Priya  29.0     Will visit again!!!ðŸ˜ŠðŸ˜Š      5
# 5             6          -   NaN                Bad experience!!    2.5
# 6             7      Meena  31.0                 Too expensive!!    NaN
# 7             8   Arjun###  24.0              Superb ambience!!!    4.2
# 8             9     Sam, K  27.0                  Not clean ðŸ¤¢      3
# 9            10    Kavitha  26.0             Awesome â¤ï¸ food    4.8
# 10           11   Rajesh!!  30.0       Wait time was too long...    2.9
# 11           12      Sneha   NaN                          Good!!      ?
# ...

# %%
data.dtypes
# Out:
# customer_id        int64
# name              object
# age              float64
# feedback_text     object
# rating            object
# city              object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    30 non-null     int64
#  1   name           27 non-null     object
#  2   age            25 non-null     float64
#  3   feedback_text  28 non-null     object
#  4   rating         29 non-null     object
#  5   city           25 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.5+ KB

# %%
data.describe()
# Out:
#        customer_id        age
# count    30.000000  25.000000
# mean     15.500000  28.240000
# std       8.803408   4.075128
# min       1.000000  22.000000
# 25%       8.250000  25.000000
# 50%      15.500000  28.000000
# 75%      22.750000  30.000000
# max      30.000000  40.000000

# %%
data.columns
# Out:
# Index(['customer_id', 'name', 'age', 'feedback_text', 'rating', 'city'], dtype='object')

# %%
data['age'].mean()
# Out:
# np.float64(28.240000000000002)

# %%
data['name'] = data['name'].fillna("Unknown")
data
data['age']=data['age'].fillna(data['age'].mean())
data
# Out:
#     customer_id      name    age                   feedback_text rating  \
# 0             1  John Doe  28.00                 Good service!!!    4.5
# 1             2  Mary Ann  28.24  Nice place but food was cold..    3.8
# 2             3   Unknown  35.00              Loved it!!! â¤ï¸      ?
# 3             4     Rahul  22.00                             NaN      4
# 4             5     Priya  29.00     Will visit again!!!ðŸ˜ŠðŸ˜Š      5
# 5             6            28.24                Bad experience!!    2.5
# 6             7     Meena  31.00                 Too expensive!!    NaN
# 7             8     Arjun  24.00              Superb ambience!!!    4.2
# 8             9     Sam K  27.00                  Not clean ðŸ¤¢      3
# 9            10   Kavitha  26.00             Awesome â¤ï¸ food    4.8
# 10           11    Rajesh  30.00       Wait time was too long...    2.9
# 11           12     Sneha  28.24                          Good!!      ?
# ...

# %%
data['age']=data['age'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    30 non-null     int64
#  1   name           30 non-null     object
#  2   age            30 non-null     int64
#  3   feedback_text  28 non-null     object
#  4   rating         29 non-null     object
#  5   city           25 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.5+ KB

# %%
import re
#re.sub(pattern, replace, string) sub substite function and r raw string /,\,~ all consider as normal character
#^invert symbol
# Remove emojis / weird symbols
data['feedback_text'] = data['feedback_text'].apply(lambda x: re.sub(r'[^\x00-\x7F]+','', str(x)))
data
#\s = “space character”,\w = “word character”
#str.strip() start and end
#re.sub() / str.replace() entier string
data['feedback_text'] = data['feedback_text'].apply(lambda x: re.sub(r'[^\w\s]', '', str(x)))
data
# Out:
#     customer_id      name  age                 feedback_text rating  \
# 0             1  John Doe   28                  Good service    4.5
# 1             2  Mary Ann   28  Nice place but food was cold    3.8
# 2             3   Unknown   35                     Loved it       ?
# 3             4     Rahul   22                           nan      4
# 4             5     Priya   29              Will visit again      5
# 5             6             28                Bad experience    2.5
# 6             7     Meena   31                 Too expensive    NaN
# 7             8     Arjun   24               Superb ambience    4.2
# 8             9     Sam K   27                    Not clean       3
# 9            10   Kavitha   26                 Awesome  food    4.8
# 10           11    Rajesh   30        Wait time was too long    2.9
# 11           12     Sneha   28                          Good      ?
# 12           13       Anu   25               Service average      ?
# ...

# %%
data['feedback_text'] = data['feedback_text'].fillna("Unknown")
data
# Out:
#     customer_id      name  age feedback_text rating         city
# 0             1  John Doe   28       unknown    4.5     New York
# 1             2  Mary Ann   28       unknown    3.8  Los Angeles
# 2             3   Unknown   35       unknown      ?      Chicago
# 3             4     Rahul   22       unknown      4          NaN
# 4             5     Priya   29       unknown      5       Mumbai
# 5             6             28       unknown    2.5        Delhi
# 6             7     Meena   31       unknown    NaN      Chennai
# 7             8     Arjun   24       unknown    4.2    Bangalore
# 8             9     Sam K   27       unknown      3    Hyderabad
# 9            10   Kavitha   26       unknown    4.8         Pune
# 10           11    Rajesh   30       unknown    2.9        Delhi
# 11           12     Sneha   28       unknown      ?          NaN
# 12           13       Anu   25       unknown      ?        Kochi
# ...

# %%
data.iloc[3,3]
type(data.loc[3, 'city'])
# Out:
# float

# %%
data.iloc[3,5]
type(data.loc[3, 'feedback_text'])
# Out:
# str

# %%
import numpy as np

data['feedback_text'].replace(['nan', np.nan], 'Unknown', inplace=True)
data
# Out:
#     customer_id      name  age                 feedback_text rating  \
# 0             1  John Doe   28                  Good service     45
# 1             2  Mary Ann   28  Nice place but food was cold     38
# 2             3   Unknown   35                     Loved it     nan
# 3             4     Rahul   22                       Unknown      4
# 4             5     Priya   29              Will visit again      5
# 5             6             28                Bad experience     25
# 6             7     Meena   31                 Too expensive    nan
# 7             8     Arjun   24               Superb ambience     42
# 8             9     Sam K   27                    Not clean       3
# 9            10   Kavitha   26                 Awesome  food     48
# 10           11    Rajesh   30        Wait time was too long     29
# 11           12     Sneha   28                          Good    nan
# 12           13       Anu   25               Service average    nan
# ...

# %%
import numpy as np

data['rating'].replace(['known', 'Unknown', 'nan', '', 'NaN', ' '], np.nan, inplace=True)
data
data['rating'] = pd.to_numeric(data['rating'], errors='coerce')
data.dtypes
# Out:
# customer_id        int64
# name              object
# age                int64
# feedback_text     object
# rating           float64
# city              object
# dtype: object

# %%
data['rating']=data['rating'].fillna(data['rating'].mean())
data
data['rating'].mean()
data
# Out:
#     customer_id      name  age                 feedback_text  rating  \
# 0             1  John Doe   28                  Good service  29.125
# 1             2  Mary Ann   28  Nice place but food was cold  29.125
# 2             3   Unknown   35                     Loved it   29.125
# 3             4     Rahul   22                       Unknown  29.125
# 4             5     Priya   29              Will visit again  29.125
# 5             6             28                Bad experience  29.125
# 6             7     Meena   31                 Too expensive  29.125
# 7             8     Arjun   24               Superb ambience  29.125
# 8             9     Sam K   27                    Not clean   29.125
# 9            10   Kavitha   26                 Awesome  food  29.125
# 10           11    Rajesh   30        Wait time was too long  29.125
# 11           12     Sneha   28                          Good  29.125
# 12           13       Anu   25               Service average  29.125
# ...

# %%
import pandas as pd
data = pd.read_csv("customer_feedback1.csv")
#replace
data['name']=data['name'].str.replace('-','')
data['name']=data['name'].str.replace(',','')
data['name']=data['name'].str.strip("#")
data['name']=data['name'].str.strip("@")
data['name']=data['name'].str.strip("$")
data['name']=data['name'].str.strip("!")
data['name']=data['name'].str.strip(",")
data['name']=data['name'].str.strip("?")
data
data['name'] = data['name'].fillna("Unknown")
data
#agen mean value
data['age']=data['age'].fillna(data['age'].mean())
data
#convert type into int
data['age']=data['age'].astype(int)
data.info()
import re
#re.sub(pattern, replace, string) sub substite function and r raw string /,\,~ all consider as normal character
#^invert symbol
# Remove emojis / weird symbols
data['feedback_text'] = data['feedback_text'].apply(lambda x: re.sub(r'[^\x00-\x7F]+','', str(x)))
data
#\s = “space character”,\w = “word character”
#str.strip() start and end
#re.sub() / str.replace() entier string
data['feedback_text'] = data['feedback_text'].apply(lambda x: re.sub(r'[^\w\s]', '', str(x)))
data
import numpy as np
data.dtypes
#re.sub() / str.replace() entier string
data['rating'] = data['rating'].apply(lambda x: re.sub(r'[^\w\s]', '', str(x)))
data
data.dtypes
data['city'] = data['city'].fillna("Unknown")
data

import numpy as np

data['rating'].replace(['known', 'Unknown', 'nan', '', 'NaN', ' '], np.nan, inplace=True)
data
data['rating'] = pd.to_numeric(data['rating'], errors='coerce')
data.dtypes
data

data['rating']=data['rating'].fillna(data['rating'].mean())
data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    30 non-null     int64
#  1   name           30 non-null     object
#  2   age            30 non-null     int64
#  3   feedback_text  28 non-null     object
#  4   rating         29 non-null     object
#  5   city           25 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.5+ KB
#     customer_id      name  age                 feedback_text  rating  \
# 0             1  John Doe   28                  Good service  45.000
# 1             2  Mary Ann   28  Nice place but food was cold  38.000
# 2             3   Unknown   35                     Loved it   29.125
# 3             4     Rahul   22                           nan   4.000
# 4             5     Priya   29              Will visit again   5.000
# ...

# %%
data['rating'].mean()
data['feedback_text'].replace(['nan','NaN', ' '], np.nan, inplace=True)
data
data['feedback_text'] = data['feedback_text'].fillna("Unknown")
data
data['name'].replace([''], np.nan, inplace=True)
data
data['name'] = data['name'].fillna("Unknown")
data
# Out:
#     customer_id      name  age                 feedback_text  rating  \
# 0             1  John Doe   28                  Good service  45.000
# 1             2  Mary Ann   28  Nice place but food was cold  38.000
# 2             3   Unknown   35                     Loved it   29.125
# 3             4     Rahul   22                       Unknown   4.000
# 4             5     Priya   29              Will visit again   5.000
# 5             6   Unknown   28                Bad experience  25.000
# 6             7     Meena   31                 Too expensive  29.125
# 7             8     Arjun   24               Superb ambience  42.000
# 8             9     Sam K   27                    Not clean    3.000
# 9            10   Kavitha   26                 Awesome  food  48.000
# 10           11    Rajesh   30        Wait time was too long  29.000
# 11           12     Sneha   28                          Good  29.125
# 12           13       Anu   25               Service average  29.125
# ...
